# %%
# !pip install kaggle
# !mkdir -p ~/.kaggle
# !cp /home/Personal_Projects/Databricks/work/.kaggle/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !pip install boto3
# !python data_pipeline.py
# Out:
# Requirement already satisfied: kaggle in /opt/conda/lib/python3.11/site-packages (1.7.4.5)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.11/site-packages (from kaggle) (6.1.0)
# Requirement already satisfied: certifi>=14.05.14 in /opt/conda/lib/python3.11/site-packages (from kaggle) (2023.7.22)
# Requirement already satisfied: charset-normalizer in /opt/conda/lib/python3.11/site-packages (from kaggle) (3.3.0)
# Requirement already satisfied: idna in /opt/conda/lib/python3.11/site-packages (from kaggle) (3.4)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.11/site-packages (from kaggle) (4.24.3)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/conda/lib/python3.11/site-packages (from kaggle) (2.8.2)
# Requirement already satisfied: python-slugify in /opt/conda/lib/python3.11/site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from kaggle) (2.31.0)
# Requirement already satisfied: setuptools>=21.0.0 in /opt/conda/lib/python3.11/site-packages (from kaggle) (68.2.2)
# Requirement already satisfied: six>=1.10 in /opt/conda/lib/python3.11/site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: text-unidecode in /opt/conda/lib/python3.11/site-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from kaggle) (4.66.1)
# Requirement already satisfied: urllib3>=1.15.1 in /opt/conda/lib/python3.11/site-packages (from kaggle) (2.0.7)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.11/site-packages (from kaggle) (0.5.1)
# Requirement already satisfied: boto3 in /opt/conda/lib/python3.11/site-packages (1.40.38)
# Requirement already satisfied: botocore<1.41.0,>=1.40.38 in /opt/conda/lib/python3.11/site-packages (from boto3) (1.40.38)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /opt/conda/lib/python3.11/site-packages (from boto3) (0.14.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.11/site-packages (from botocore<1.41.0,>=1.40.38->boto3) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.11/site-packages (from botocore<1.41.0,>=1.40.38->boto3) (2.0.7)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.38->boto3) (1.16.0)
# Initializing Spark Session...
# 25/09/25 13:41:24 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Spark Session initialized.
#
# =============================================
#   Starting Telco Churn Data Lakehouse Pipeline
# =============================================
#
#
# >>> Executing Landing Stage...
#
# --- Starting Landing Stage ---
# Downloading Kaggle dataset to /home/Personal_Projects/Databricks/work/datasets...
# Dataset URL: https://www.kaggle.com/datasets/blastchar/telco-customer-churn
# Kaggle dataset downloaded.
# Unzipping /home/Personal_Projects/Databricks/work/datasets/telco-customer-churn.zip...
# Dataset unzipped.
# Uploading /home/Personal_Projects/Databricks/work/datasets/WA_Fn-UseC_-Telco-Customer-Churn.csv to s3://databricks-one/raw/telco.csv...
# CSV file uploaded to S3.
# Creating database raw_data at s3a://databricks-one/raw/ if it doesn't exist...
# Database raw_data ensured.
# Reading raw CSV from S3 for verification: s3a://databricks-one/raw/telco.csv
# First 10 rows of raw data:
# +----------+------+-------------+-------+----------+------+------------+----------------+---------------+--------------+------------+----------------+-----------+-----------+---------------+--------------+----------------+--------------------+--------------+------------+-----+
# |customerID|gender|SeniorCitizen|Partner|Dependents|tenure|PhoneService|   MultipleLines|InternetService|OnlineSecurity|OnlineBackup|DeviceProtection|TechSupport|StreamingTV|StreamingMovies|      Contract|PaperlessBilling|       PaymentMethod|MonthlyCharges|TotalCharges|Churn|
# +----------+------+-------------+-------+----------+------+------------+----------------+---------------+--------------+------------+----------------+-----------+-----------+---------------+--------------+----------------+--------------------+--------------+------------+-----+
# |7590-VHVEG|Female|            0|    Yes|        No|     1|          No|No phone service|            DSL|            No|         Yes|              No|         No|         No|             No|Month-to-month|             Yes|    Electronic check|         29.85|       29.85|   No|
# |5575-GNVDE|  Male|            0|     No|        No|    34|         Yes|              No|            DSL|           Yes|          No|             Yes|         No|         No|             No|      One year|              No|        Mailed check|         56.95|      1889.5|   No|
# |3668-QPYBK|  Male|            0|     No|        No|     2|         Yes|              No|            DSL|           Yes|         Yes|              No|         No|         No|             No|Month-to-month|             Yes|        Mailed check|         53.85|      108.15|  Yes|
# |7795-CFOCW|  Male|            0|     No|        No|    45|          No|No phone service|            DSL|           Yes|          No|             Yes|        Yes|         No|             No|      One year|              No|Bank transfer (au...|          42.3|     1840.75|   No|
# |9237-HQITU|Female|            0|     No|        No|     2|         Yes|              No|    Fiber optic|            No|          No|              No|         No|         No|             No|Month-to-month|             Yes|    Electronic check|          70.7|      151.65|  Yes|
# |9305-CDSKC|Female|            0|     No|        No|     8|         Yes|             Yes|    Fiber optic|            No|          No|             Yes|         No|        Yes|            Yes|Month-to-month|             Yes|    Electronic check|         99.65|       820.5|  Yes|
# |1452-KIOVK|  Male|            0|     No|       Yes|    22|         Yes|             Yes|    Fiber optic|            No|         Yes|              No|         No|        Yes|             No|Month-to-month|             Yes|Credit card (auto...|          89.1|      1949.4|   No|
# |6713-OKOMC|Female|            0|     No|        No|    10|          No|No phone service|            DSL|           Yes|          No|              No|         No|         No|             No|Month-to-month|              No|        Mailed check|         29.75|       301.9|   No|
# |7892-POOKP|Female|            0|    Yes|        No|    28|         Yes|             Yes|    Fiber optic|            No|          No|             Yes|        Yes|        Yes|            Yes|Month-to-month|             Yes|    Electronic check|         104.8|     3046.05|  Yes|
# |6388-TABGU|  Male|            0|     No|       Yes|    62|         Yes|              No|            DSL|           Yes|         Yes|              No|         No|         No|             No|      One year|              No|Bank transfer (au...|         56.15|     3487.95|   No|
# +----------+------+-------------+-------+----------+------+------------+----------------+---------------+--------------+------------+----------------+-----------+-----------+---------------+--------------+----------------+--------------------+--------------+------------+-----+
# only showing top 10 rows
#
# Raw data schema:
# root
#  |-- customerID: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- SeniorCitizen: integer (nullable = true)
#  |-- Partner: string (nullable = true)
#  |-- Dependents: string (nullable = true)
#  |-- tenure: integer (nullable = true)
#  |-- PhoneService: string (nullable = true)
#  |-- MultipleLines: string (nullable = true)
#  |-- InternetService: string (nullable = true)
#  |-- OnlineSecurity: string (nullable = true)
#  |-- OnlineBackup: string (nullable = true)
#  |-- DeviceProtection: string (nullable = true)
#  |-- TechSupport: string (nullable = true)
#  |-- StreamingTV: string (nullable = true)
#  |-- StreamingMovies: string (nullable = true)
#  |-- Contract: string (nullable = true)
#  |-- PaperlessBilling: string (nullable = true)
#  |-- PaymentMethod: string (nullable = true)
#  |-- MonthlyCharges: double (nullable = true)
#  |-- TotalCharges: string (nullable = true)
#  |-- Churn: string (nullable = true)
#
# --- Landing Stage Finished ---
#
# >>> Executing Bronze Stage...
#
# --- Starting Bronze Stage ---
# Creating database bronze at s3a://databricks-one/telco/bronze/ if it doesn't exist...
# Database bronze ensured.
# Reading raw CSV from s3a://databricks-one/raw/telco.csv...
# Raw DataFrame loaded with 7043 rows.
#
# --- Data Validation for Raw Data ---
# INFO: Raw Data DataFrame has 7043 rows.
# --- Raw Data Validation PASSED ---
# Saving DataFrame to s3a://databricks-one/telco/bronze/telco_churn_parquet and registering external table bronze.telco_churn_parquet...
# External table bronze.telco_churn_parquet registered.
# Querying bronze.telco_churn_parquet for verification...
# First 10 rows of Bronze data:
# +----------+------+-------------+-------+----------+------+------------+----------------+---------------+--------------+------------+----------------+-----------+-----------+---------------+--------------+----------------+--------------------+--------------+------------+-----+
# |customerID|gender|SeniorCitizen|Partner|Dependents|tenure|PhoneService|   MultipleLines|InternetService|OnlineSecurity|OnlineBackup|DeviceProtection|TechSupport|StreamingTV|StreamingMovies|      Contract|PaperlessBilling|       PaymentMethod|MonthlyCharges|TotalCharges|Churn|
# +----------+------+-------------+-------+----------+------+------------+----------------+---------------+--------------+------------+----------------+-----------+-----------+---------------+--------------+----------------+--------------------+--------------+------------+-----+
# |7590-VHVEG|Female|            0|    Yes|        No|     1|          No|No phone service|            DSL|            No|         Yes|              No|         No|         No|             No|Month-to-month|             Yes|    Electronic check|         29.85|       29.85|   No|
# |5575-GNVDE|  Male|            0|     No|        No|    34|         Yes|              No|            DSL|           Yes|          No|             Yes|         No|         No|             No|      One year|              No|        Mailed check|         56.95|      1889.5|   No|
# |3668-QPYBK|  Male|            0|     No|        No|     2|         Yes|              No|            DSL|           Yes|         Yes|              No|         No|         No|             No|Month-to-month|             Yes|        Mailed check|         53.85|      108.15|  Yes|
# |7795-CFOCW|  Male|            0|     No|        No|    45|          No|No phone service|            DSL|           Yes|          No|             Yes|        Yes|         No|             No|      One year|              No|Bank transfer (au...|          42.3|     1840.75|   No|
# |9237-HQITU|Female|            0|     No|        No|     2|         Yes|              No|    Fiber optic|            No|          No|              No|         No|         No|             No|Month-to-month|             Yes|    Electronic check|          70.7|      151.65|  Yes|
# |9305-CDSKC|Female|            0|     No|        No|     8|         Yes|             Yes|    Fiber optic|            No|          No|             Yes|         No|        Yes|            Yes|Month-to-month|             Yes|    Electronic check|         99.65|       820.5|  Yes|
# |1452-KIOVK|  Male|            0|     No|       Yes|    22|         Yes|             Yes|    Fiber optic|            No|         Yes|              No|         No|        Yes|             No|Month-to-month|             Yes|Credit card (auto...|          89.1|      1949.4|   No|
# |6713-OKOMC|Female|            0|     No|        No|    10|          No|No phone service|            DSL|           Yes|          No|              No|         No|         No|             No|Month-to-month|              No|        Mailed check|         29.75|       301.9|   No|
# |7892-POOKP|Female|            0|    Yes|        No|    28|         Yes|             Yes|    Fiber optic|            No|          No|             Yes|        Yes|        Yes|            Yes|Month-to-month|             Yes|    Electronic check|         104.8|     3046.05|  Yes|
# |6388-TABGU|  Male|            0|     No|       Yes|    62|         Yes|              No|            DSL|           Yes|         Yes|              No|         No|         No|             No|      One year|              No|Bank transfer (au...|         56.15|     3487.95|   No|
# +----------+------+-------------+-------+----------+------+------------+----------------+---------------+--------------+------------+----------------+-----------+-----------+---------------+--------------+----------------+--------------------+--------------+------------+-----+
# only showing top 10 rows
#
# Bronze data schema:
# root
#  |-- customerID: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- SeniorCitizen: integer (nullable = true)
#  |-- Partner: string (nullable = true)
#  |-- Dependents: string (nullable = true)
#  |-- tenure: integer (nullable = true)
#  |-- PhoneService: string (nullable = true)
#  |-- MultipleLines: string (nullable = true)
#  |-- InternetService: string (nullable = true)
#  |-- OnlineSecurity: string (nullable = true)
#  |-- OnlineBackup: string (nullable = true)
#  |-- DeviceProtection: string (nullable = true)
#  |-- TechSupport: string (nullable = true)
#  |-- StreamingTV: string (nullable = true)
#  |-- StreamingMovies: string (nullable = true)
#  |-- Contract: string (nullable = true)
#  |-- PaperlessBilling: string (nullable = true)
#  |-- PaymentMethod: string (nullable = true)
#  |-- MonthlyCharges: double (nullable = true)
#  |-- TotalCharges: string (nullable = true)
#  |-- Churn: string (nullable = true)
#
#
# --- Data Validation for Bronze ---
# INFO: Bronze DataFrame has 7043 rows.
# --- Bronze Validation PASSED ---
# --- Bronze Stage Finished ---
#
# >>> Executing Silver Stage...
#
# --- Starting Silver Stage ---
# Creating database silver at s3a://databricks-one/telco/silver/ if it doesn't exist...
# Database silver ensured.
# Read 7043 rows from bronze.telco_churn_parquet.
# Applying Silver transformations...
# Silver DataFrame created with 7032 rows after transformations.
# Saving DataFrame to s3a://databricks-one/telco/silver/telco_churn and registering external table silver.telco_churn...
# External table silver.telco_churn registered.
# Querying silver.telco_churn for verification...
# First 10 rows of Silver data:
# +----------+------+-------------+-------+----------+------+------------+-------------+---------------+--------------+------------+----------------+-----------+-----------+---------------+--------------+----------------+-------------------------+--------------+------------+-----+--------+
# |customerID|gender|SeniorCitizen|Partner|Dependents|tenure|PhoneService|MultipleLines|InternetService|OnlineSecurity|OnlineBackup|DeviceProtection|TechSupport|StreamingTV|StreamingMovies|Contract      |PaperlessBilling|PaymentMethod            |MonthlyCharges|TotalCharges|Churn|IsSenior|
# +----------+------+-------------+-------+----------+------+------------+-------------+---------------+--------------+------------+----------------+-----------+-----------+---------------+--------------+----------------+-------------------------+--------------+------------+-----+--------+
# |0002-ORFBO|Female|0            |Yes    |Yes       |9     |Yes         |No           |DSL            |No            |Yes         |No              |Yes        |Yes        |No             |One year      |Yes             |Mailed check             |65.6          |593.3       |No   |false   |
# |0003-MKNFE|Male  |0            |No     |No        |9     |Yes         |Yes          |DSL            |No            |No          |No              |No         |No         |Yes            |Month-to-month|No              |Mailed check             |59.9          |542.4       |No   |false   |
# |0004-TLHLJ|Male  |0            |No     |No        |4     |Yes         |No           |Fiber optic    |No            |No          |Yes             |No         |No         |No             |Month-to-month|Yes             |Electronic check         |73.9          |280.85      |Yes  |false   |
# |0011-IGKFF|Male  |1            |Yes    |No        |13    |Yes         |No           |Fiber optic    |No            |Yes         |Yes             |No         |Yes        |Yes            |Month-to-month|Yes             |Electronic check         |98.0          |1237.85     |Yes  |true    |
# |0013-EXCHZ|Female|1            |Yes    |No        |3     |Yes         |No           |Fiber optic    |No            |No          |No              |Yes        |Yes        |No             |Month-to-month|Yes             |Mailed check             |83.9          |267.4       |Yes  |true    |
# |0013-MHZWF|Female|0            |No     |Yes       |9     |Yes         |No           |DSL            |No            |No          |No              |Yes        |Yes        |Yes            |Month-to-month|Yes             |Credit card (automatic)  |69.4          |571.45      |No   |false   |
# |0013-SMEOE|Female|1            |Yes    |No        |71    |Yes         |No           |Fiber optic    |Yes           |Yes         |Yes             |Yes        |Yes        |Yes            |Two year      |Yes             |Bank transfer (automatic)|109.7         |7904.25     |No   |true    |
# |0014-BMAQU|Male  |0            |Yes    |No        |63    |Yes         |Yes          |Fiber optic    |Yes           |No          |No              |Yes        |No         |No             |Two year      |Yes             |Credit card (automatic)  |84.65         |5377.8      |No   |false   |
# |0015-UOCOJ|Female|1            |No     |No        |7     |Yes         |No           |DSL            |Yes           |No          |No              |No         |No         |No             |Month-to-month|Yes             |Electronic check         |48.2          |340.35      |No   |true    |
# |0016-QLJIS|Female|0            |Yes    |Yes       |65    |Yes         |Yes          |DSL            |Yes           |Yes         |Yes             |Yes        |Yes        |Yes            |Two year      |Yes             |Mailed check             |90.45         |5957.9      |No   |false   |
# +----------+------+-------------+-------+----------+------+------------+-------------+---------------+--------------+------------+----------------+-----------+-----------+---------------+--------------+----------------+-------------------------+--------------+------------+-----+--------+
# only showing top 10 rows
#
# Silver data schema:
# root
#  |-- customerID: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- SeniorCitizen: integer (nullable = true)
#  |-- Partner: string (nullable = true)
#  |-- Dependents: string (nullable = true)
#  |-- tenure: integer (nullable = true)
#  |-- PhoneService: string (nullable = true)
#  |-- MultipleLines: string (nullable = true)
#  |-- InternetService: string (nullable = true)
#  |-- OnlineSecurity: string (nullable = true)
#  |-- OnlineBackup: string (nullable = true)
#  |-- DeviceProtection: string (nullable = true)
#  |-- TechSupport: string (nullable = true)
#  |-- StreamingTV: string (nullable = true)
#  |-- StreamingMovies: string (nullable = true)
#  |-- Contract: string (nullable = true)
#  |-- PaperlessBilling: string (nullable = true)
#  |-- PaymentMethod: string (nullable = true)
#  |-- MonthlyCharges: double (nullable = true)
#  |-- TotalCharges: double (nullable = true)
#  |-- Churn: string (nullable = true)
#  |-- IsSenior: boolean (nullable = true)
#
#
# --- Data Validation for Silver ---
# INFO: Silver DataFrame has 7032 rows.
# INFO: Column 'customerID' in Silver has no null values.
# INFO: Column 'tenure' in Silver has no null values.
# INFO: Column 'MonthlyCharges' in Silver has no null values.
# INFO: Column 'TotalCharges' in Silver has no null values.
# --- Silver Validation PASSED ---
# --- Silver Stage Finished ---
#
# >>> Executing Gold Stage...
#
# --- Starting Gold Stage ---
# Creating database gold at s3a://databricks-one/telco/gold/ if it doesn't exist...
# Database gold ensured.
# Read 7032 rows from silver.telco_churn.
# +----------+------+-------------+-------+----------+------+------------+-------------+---------------+--------------+------------+----------------+-----------+-----------+---------------+--------------+----------------+----------------+--------------+------------+-----+--------+
# |customerID|gender|SeniorCitizen|Partner|Dependents|tenure|PhoneService|MultipleLines|InternetService|OnlineSecurity|OnlineBackup|DeviceProtection|TechSupport|StreamingTV|StreamingMovies|Contract      |PaperlessBilling|PaymentMethod   |MonthlyCharges|TotalCharges|Churn|IsSenior|
# +----------+------+-------------+-------+----------+------+------------+-------------+---------------+--------------+------------+----------------+-----------+-----------+---------------+--------------+----------------+----------------+--------------+------------+-----+--------+
# |0002-ORFBO|Female|0            |Yes    |Yes       |9     |Yes         |No           |DSL            |No            |Yes         |No              |Yes        |Yes        |No             |One year      |Yes             |Mailed check    |65.6          |593.3       |No   |false   |
# |0003-MKNFE|Male  |0            |No     |No        |9     |Yes         |Yes          |DSL            |No            |No          |No              |No         |No         |Yes            |Month-to-month|No              |Mailed check    |59.9          |542.4       |No   |false   |
# |0004-TLHLJ|Male  |0            |No     |No        |4     |Yes         |No           |Fiber optic    |No            |No          |Yes             |No         |No         |No             |Month-to-month|Yes             |Electronic check|73.9          |280.85      |Yes  |false   |
# |0011-IGKFF|Male  |1            |Yes    |No        |13    |Yes         |No           |Fiber optic    |No            |Yes         |Yes             |No         |Yes        |Yes            |Month-to-month|Yes             |Electronic check|98.0          |1237.85     |Yes  |true    |
# |0013-EXCHZ|Female|1            |Yes    |No        |3     |Yes         |No           |Fiber optic    |No            |No          |No              |Yes        |Yes        |No             |Month-to-month|Yes             |Mailed check    |83.9          |267.4       |Yes  |true    |
# +----------+------+-------------+-------+----------+------+------------+-------------+---------------+--------------+------------+----------------+-----------+-----------+---------------+--------------+----------------+----------------+--------------+------------+-----+--------+
# only showing top 5 rows
#
# Creating Dimension Tables...
# dim_customer has 7032 rows.
#
# --- Data Validation for Gold - Dim Customer ---
# INFO: Gold - Dim Customer DataFrame has 7032 rows.
# INFO: Column 'customerID' in Gold - Dim Customer has no null values.
# --- Gold - Dim Customer Validation PASSED ---
# dim_contract has 3 rows.
#
# --- Data Validation for Gold - Dim Contract ---
# INFO: Gold - Dim Contract DataFrame has 3 rows.
# --- Gold - Dim Contract Validation PASSED ---
# dim_services has 3 rows.
#
# --- Data Validation for Gold - Dim Services ---
# INFO: Gold - Dim Services DataFrame has 3 rows.
# --- Gold - Dim Services Validation PASSED ---
# dim_payment has 4 rows.
#
# --- Data Validation for Gold - Dim Payment ---
# INFO: Gold - Dim Payment DataFrame has 4 rows.
# --- Gold - Dim Payment Validation PASSED ---
# Creating Fact Table...
# fact_churn initially has 7032 rows.
#
# --- Data Validation for Gold - Fact Churn (Pre-join) ---
# INFO: Gold - Fact Churn (Pre-join) DataFrame has 7032 rows.
# INFO: Column 'customerID' in Gold - Fact Churn (Pre-join) has no null values.
# INFO: Column 'Contract' in Gold - Fact Churn (Pre-join) has no null values.
# INFO: Column 'InternetService' in Gold - Fact Churn (Pre-join) has no null values.
# INFO: Column 'PaymentMethod' in Gold - Fact Churn (Pre-join) has no null values.
# --- Gold - Fact Churn (Pre-join) Validation PASSED ---
# Saving Gold Layer to S3 and registering tables...
# Saving DataFrame to s3a://databricks-one/telco/gold/dim_customer and registering external table gold.dim_customer...
# External table gold.dim_customer registered.
# Saving DataFrame to s3a://databricks-one/telco/gold/dim_contract and registering external table gold.dim_contract...
# External table gold.dim_contract registered.
# Saving DataFrame to s3a://databricks-one/telco/gold/dim_services and registering external table gold.dim_services...
# External table gold.dim_services registered.
# Saving DataFrame to s3a://databricks-one/telco/gold/dim_payment and registering external table gold.dim_payment...
# External table gold.dim_payment registered.
# fact_churn after FK validation has 7032 rows.
#
# --- Data Validation for Gold - Fact Churn ---
# INFO: Gold - Fact Churn DataFrame has 7032 rows.
# INFO: Column 'customerID' in Gold - Fact Churn has no null values.
# INFO: Column 'Contract' in Gold - Fact Churn has no null values.
# INFO: Column 'InternetService' in Gold - Fact Churn has no null values.
# INFO: Column 'PaymentMethod' in Gold - Fact Churn has no null values.
# --- Gold - Fact Churn Validation PASSED ---
# Saving DataFrame to s3a://databricks-one/telco/gold/fact_churn and registering external table gold.fact_churn...
# External table gold.fact_churn registered.
#
# Verifying Gold tables:
# +----------+------+-------------+--------+-------+----------+------------+-------------+
# |customerID|gender|SeniorCitizen|IsSenior|Partner|Dependents|PhoneService|MultipleLines|
# +----------+------+-------------+--------+-------+----------+------------+-------------+
# |0002-ORFBO|Female|0            |false   |Yes    |Yes       |Yes         |No           |
# |0003-MKNFE|Male  |0            |false   |No     |No        |Yes         |Yes          |
# |0004-TLHLJ|Male  |0            |false   |No     |No        |Yes         |No           |
# |0011-IGKFF|Male  |1            |true    |Yes    |No        |Yes         |No           |
# |0013-EXCHZ|Female|1            |true    |Yes    |No        |Yes         |No           |
# +----------+------+-------------+--------+-------+----------+------------+-------------+
#
# +----------+--------------+---------------+----------------+------+--------------+------------+
# |customerID|Contract      |InternetService|PaymentMethod   |tenure|MonthlyCharges|TotalCharges|
# +----------+--------------+---------------+----------------+------+--------------+------------+
# |0002-ORFBO|One year      |DSL            |Mailed check    |9     |65.6          |593.3       |
# |0003-MKNFE|Month-to-month|DSL            |Mailed check    |9     |59.9          |542.4       |
# |0004-TLHLJ|Month-to-month|Fiber optic    |Electronic check|4     |73.9          |280.85      |
# |0011-IGKFF|Month-to-month|Fiber optic    |Electronic check|13    |98.0          |1237.85     |
# |0013-EXCHZ|Month-to-month|Fiber optic    |Mailed check    |3     |83.9          |267.4       |
# +----------+--------------+---------------+----------------+------+--------------+------------+
#
# --- Gold Stage Finished ---
#
# =============================================
#  Telco Churn Data Lakehouse Pipeline COMPLETED Successfully!
# =============================================
#
# Stopping Spark Session...
# Spark Session stopped.
